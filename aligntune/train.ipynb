# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.10 python3.10-distutils python3.10-venv python3-pip -y

# python3.10 varsayılan hale getirme:
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1

# Yeni pip kurulumu
# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3.10
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,244 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [77.5 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,715 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,659 kB]
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,910 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [55.7 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,544 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,420 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,200 kB]
# Fetched 24.2 MB in 2s (9,815 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.10-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# python3.10 is already the newest version (3.10.12-1~22.04.9).
# python3.10 set to manually installed.
# The following additional packages will be installed:
#   python3-pip-whl python3-setuptools python3-setuptools-whl python3-wheel
# Suggested packages:
#   python-setuptools-doc
# The following NEW packages will be installed:
#   python3-pip python3-pip-whl python3-setuptools python3-setuptools-whl
#   python3-wheel python3.10-venv
# 0 upgraded, 6 newly installed, 0 to remove and 43 not upgraded.
# Need to get 4,151 kB of archives.
# After this operation, 11.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-setuptools all 59.6.0-1.2ubuntu0.22.04.2 [340 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-wheel all 0.37.1-2ubuntu0.22.04.1 [32.0 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip all 22.0.2+dfsg-1ubuntu0.5 [1,306 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip-whl all 22.0.2+dfsg-1ubuntu0.5 [1,680 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-setuptools-whl all 59.6.0-1.2ubuntu0.22.04.2 [788 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3.10-venv amd64 3.10.12-1~22.04.9 [5,722 B]
# Fetched 4,151 kB in 1s (3,179 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 6.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package python3-setuptools.
# (Reading database ... 126101 files and directories currently installed.)
# Preparing to unpack .../0-python3-setuptools_59.6.0-1.2ubuntu0.22.04.2_all.deb ...
# Unpacking python3-setuptools (59.6.0-1.2ubuntu0.22.04.2) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../1-python3-wheel_0.37.1-2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../2-python3-pip_22.0.2+dfsg-1ubuntu0.5_all.deb ...
# Unpacking python3-pip (22.0.2+dfsg-1ubuntu0.5) ...
# Selecting previously unselected package python3-pip-whl.
# Preparing to unpack .../3-python3-pip-whl_22.0.2+dfsg-1ubuntu0.5_all.deb ...
# Unpacking python3-pip-whl (22.0.2+dfsg-1ubuntu0.5) ...
# Selecting previously unselected package python3-setuptools-whl.
# Preparing to unpack .../4-python3-setuptools-whl_59.6.0-1.2ubuntu0.22.04.2_all.deb ...
# Unpacking python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.2) ...
# Selecting previously unselected package python3.10-venv.
# Preparing to unpack .../5-python3.10-venv_3.10.12-1~22.04.9_amd64.deb ...
# Unpacking python3.10-venv (3.10.12-1~22.04.9) ...
# Setting up python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.2) ...
# Setting up python3-setuptools (59.6.0-1.2ubuntu0.22.04.2) ...
# Setting up python3-pip-whl (22.0.2+dfsg-1ubuntu0.5) ...
# Setting up python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Setting up python3-pip (22.0.2+dfsg-1ubuntu0.5) ...
# Setting up python3.10-venv (3.10.12-1~22.04.9) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.8 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.2
#     Uninstalling pip-22.0.2:
#       Successfully uninstalled pip-22.0.2
# Successfully installed pip-25.1.1

# %%
# %cd /content/drive/MyDrive/AlignTune-VLTransformer
# !python3.10 -m pip install -e .
# Out:
# /content/drive/MyDrive/AlignTune-VLTransformer
# Obtaining file:///content/drive/MyDrive/AlignTune-VLTransformer
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting hydra-core (from align-tune==0.1.0)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting lightning>=2.2.1 (from align-tune==0.1.0)
#   Downloading lightning-2.5.1.post0-py3-none-any.whl.metadata (39 kB)
# Collecting wandb>=0.16.4 (from align-tune==0.1.0)
#   Downloading wandb-0.19.10-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting pandas>=2.2.1 (from align-tune==0.1.0)
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting numpy>=1.26.4 (from align-tune==0.1.0)
#   Downloading numpy-2.2.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting typer>=0.4.0 (from align-tune==0.1.0)
#   Downloading typer-0.15.3-py3-none-any.whl.metadata (15 kB)
# Collecting pillow>=10.0.0 (from align-tune==0.1.0)
#   Downloading pillow-11.2.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting torchvision>=0.16.1 (from align-tune==0.1.0)
#   Downloading torchvision-0.22.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting albumentations>=1.4.22 (from align-tune==0.1.0)
#   Downloading albumentations-2.0.6-py3-none-any.whl.metadata (43 kB)
# Collecting tqdm>=4.64.0 (from align-tune==0.1.0)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting safetensors>=0.3.0 (from align-tune==0.1.0)
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting transformers>=4.37.0 (from align-tune==0.1.0)
#   Downloading transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# Collecting nltk>=3.8.1 (from align-tune==0.1.0)
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting peft>=0.4.0 (from align-tune==0.1.0)
#   Downloading peft-0.15.2-py3-none-any.whl.metadata (13 kB)
# Collecting scipy>=1.10.0 (from albumentations>=1.4.22->align-tune==0.1.0)
#   Downloading scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting PyYAML (from albumentations>=1.4.22->align-tune==0.1.0)
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting pydantic>=2.9.2 (from albumentations>=1.4.22->align-tune==0.1.0)
#   Downloading pydantic-2.11.4-py3-none-any.whl.metadata (66 kB)
# Collecting albucore==0.0.24 (from albumentations>=1.4.22->align-tune==0.1.0)
#   Downloading albucore-0.0.24-py3-none-any.whl.metadata (5.3 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations>=1.4.22->align-tune==0.1.0)
#   Downloading opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting stringzilla>=3.10.4 (from albucore==0.0.24->albumentations>=1.4.22->align-tune==0.1.0)
#   Downloading stringzilla-3.12.5-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl.metadata (80 kB)
# Collecting simsimd>=5.9.2 (from albucore==0.0.24->albumentations>=1.4.22->align-tune==0.1.0)
#   Downloading simsimd-6.2.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (66 kB)
# Collecting fsspec<2026.0,>=2022.5.0 (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.2.1->align-tune==0.1.0)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting packaging<25.0,>=20.0 (from lightning>=2.2.1->align-tune==0.1.0)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting torch<4.0,>=2.1.0 (from lightning>=2.2.1->align-tune==0.1.0)
#   Downloading torch-2.7.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning>=2.2.1->align-tune==0.1.0)
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting typing-extensions<6.0,>=4.4.0 (from lightning>=2.2.1->align-tune==0.1.0)
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting pytorch-lightning (from lightning>=2.2.1->align-tune==0.1.0)
#   Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata (20 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading aiohttp-3.11.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning>=2.2.1->align-tune==0.1.0) (59.6.0)
# Collecting filelock (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting sympy>=1.13.3 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch<4.0,>=2.1.0->lightning>=2.2.1->align-tune==0.1.0)
